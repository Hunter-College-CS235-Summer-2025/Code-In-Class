# %%
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
subfields = {
    "Data Science": 4,
    "Game Development": 6,
    "Web Development": 4,
    "Machine Learning": 3,
    "Cybersecurity": 6,
    "Software Development": 6,
    "Computer Vision": 0,
    "Mobile App Development": 2,
    "Data Analytics": 1
}

# %%
wordcloud = WordCloud(
    width=2400,
    height=960,
    background_color='black',
    colormap='Spectral',
    prefer_horizontal=0.1,
    contour_width=2,
    contour_color='steelblue',
).generate_from_frequencies(subfields)

# %%
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off')
plt.savefig('CS235_banner.png', dpi=dpi, pad_inches=0)
plt.show()
